# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt

from model.velocity_only.base import *
from model.velocity_only import baseline
from plot import plot

# %%
fig, ax = plt.subplots(figsize=(4, 2))
for y_ in own_force:
    ax.plot(timestep, y_, color="C0", alpha=0.1, lw=0.5)
ax.plot([], [], color="C0", label="own force")

for y_ in push_effect:
    ax.plot(timestep, y_, color="C1", alpha=0.1, lw=0.3)
ax.plot([], [], color="C1", label="push effect")

for y_ in own_force + push_effect:
    ax.plot(timestep, y_, color="C2", alpha=0.1, lw=0.3)
ax.plot([], [], color="C2", label="own force + push effect")

ax.set_xlabel("context (time)")
ax.set_ylabel("velocity")
ax.axhline(y=0.0, ls="--", color="0.4")
ax.legend();

# %%
fig, axes = plt.subplots(ncols=n_action, nrows=n_timestep, figsize=(2, 5))
for a in range(n_action):
    for t in range(n_timestep):
        ax = axes[t, a]
        img = transition_velocity_tavv[t, a, :, :]
        ax.imshow(img, aspect=1, vmin=0, vmax=1.0)
        ax.get_xaxis().set_ticks([])
        ax.axes.get_yaxis().set_ticks([])

# %%
fig, axes = plt.subplots(ncols=n_velocity)
for i, ax in enumerate(axes):
    img = transition_position_pvp[:, i, :]
    ax.imshow(img, aspect=1)
    ax.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])

# %%
baselines = baseline.run()
plot.runs(*baselines)
